# %% [markdown]
# <a href="https://colab.research.google.com/github/Balla01/assignments-HW-Saver-LLP/blob/main/IN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Example_Technical_Skills.csv")
af = pd.read_csv("/content/Raw_Skills_Dataset.csv")

# %%
af
# Out:
#                                             RAW DATA
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
# [34116 rows x 1 columns]

# %%
df
# Out:
#                          Technology Skills
# 0                      SAP Fiori Developer
# 1    Oracle Instance Management & Strategy
# 2             Boomi Master Data Management
# 3    Digital Manufacturing on Cloud ( DMC)
# 4                                   DevOps
# ..                                     ...
# 974        Oracle Cloud Revenue Management
# 975       Oracle EBS Grid Contral Mgt Pack
# 976         Amazon Elastic MapReduce (EMR)
# 977                            Apache Kudu
# 978                             Oracle ESB
#
# [979 rows x 1 columns]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def rem_punc(text):
  new_text="".join([c for c in text if c not in string.punctuation])
  return new_text
df['clean_data']=df['Technology Skills'].apply(lambda x: rem_punc(x))

# %%
df['lower_text']=df['clean_data'].apply(lambda x:x.lower())

# %%
df['tokenize'] = df.apply(lambda row: nltk.word_tokenize(row['lower_text']),axis=1)

# %%
stopwords=nltk.corpus.stopwords.words('english')

# %%
def remove_stopwords(txt):
  text=[word for word in txt if word not in stopwords]
  return text
df['stop_free']=df['tokenize'].apply(lambda x: remove_stopwords(x))

# %%
df
# Out:
#                          Technology Skills  \
# 0                      SAP Fiori Developer
# 1    Oracle Instance Management & Strategy
# 2             Boomi Master Data Management
# 3    Digital Manufacturing on Cloud ( DMC)
# 4                                   DevOps
# ..                                     ...
# 974        Oracle Cloud Revenue Management
# 975       Oracle EBS Grid Contral Mgt Pack
# 976         Amazon Elastic MapReduce (EMR)
# 977                            Apache Kudu
# 978                             Oracle ESB
#
#                                clean_data  \
# 0                     SAP Fiori Developer
# 1    Oracle Instance Management  Strategy
# 2            Boomi Master Data Management
# 3     Digital Manufacturing on Cloud  DMC
# 4                                  DevOps
# ..                                    ...
# 974       Oracle Cloud Revenue Management
# 975      Oracle EBS Grid Contral Mgt Pack
# 976          Amazon Elastic MapReduce EMR
# ...

# %%
def rem_punc(text):
  new_text="".join([c for c in text if c not in string.punctuation])
  return new_text
af['clean_data']=af['RAW DATA'].apply(lambda x: rem_punc(x))

# %%
af['lower_text1']=af['clean_data'].apply(lambda x:x.lower())

# %%
af['tokenize1'] = af.apply(lambda row: nltk.word_tokenize(row['lower_text1']),axis=1)

# %%
def remove_stopwords(txt):
  text=[word for word in txt if word not in stopwords]
  return text
af['stop_free1']=af['tokenize1'].apply(lambda x: remove_stopwords(x))

# %%
af
# Out:
#                                             RAW DATA  \
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
#                                         clean_data  \
# 0                                         What ifs
# 1                                        seniority
# 2                                      familiarity
# 3                                  functionalities
# 4                                          Lambdas
# ...

# %%
skills=['python']
for i in range(979):
  skills.extend(df['stop_free'][i])

# %%
skills
# Out:
# ['python',
#  'sap',
#  'fiori',
#  'developer',
#  'oracle',
#  'instance',
#  'management',
#  'strategy',
#  'boomi',
#  'master',
#  'data',
#  'management',
#  'digital',
#  'manufacturing',
#  'cloud',
#  'dmc',
#  'devops',
#  'ca',
#  'sam',
#  'openshift',
#  'acxiom',
#  'data',
#  'analytics',
#  'sap',
#  'digital',
#  'boardroom',
#  'seeburger',
#  'bis',
#  'sap',
#  'transport',
#  'management',
#  'peoplesoft',
#  'workflow',
#  'nice',
#  'actimize',
#  'oracle',
#  'access',
#  'manager',
#  'sap',
#  'electronic',
#  'data',
#  'interchange',
#  'edi',
#  'ideas',
#  'crowdsourcing',
#  'peoplesoft',
#  'workforce',
#  'planning',
#  'sap',
#  'benefits',
#  'onesource',
#  'rd',
#  'credit',
#  'manager',
#  'sap',
#  'consignment',
#  'ms',
#  'bot',
#  'framework',
#  'ibm',
#  'websphere',
#  'application',
#  'server',
#  'microsoft',
#  'azure',
#  'ad',
#  'domain',
#  'services',
#  'sap',
#  'ibp',
#  'bpc',
#  'oracle',
#  'hyperion',
#  'capital',
# ...

# %%
af['lable']=None

# %%
for i in range(34116):
  for j in af['stop_free1'][i]:
    for k in skills:
      if j==k:
        af['lable'][i]="technical"

# %%
af
# Out:
#                                             RAW DATA  \
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
#                                         clean_data  \
# 0                                         What ifs
# 1                                        seniority
# 2                                      familiarity
# 3                                  functionalities
# 4                                          Lambdas
# ...

# %%
for i in range(34116):
  if af['lable'][i]==None:
    af['lable'][i]='Non technical'

# %%
af
# Out:
#                                             RAW DATA  \
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
#                                         clean_data  \
# 0                                         What ifs
# 1                                        seniority
# 2                                      familiarity
# 3                                  functionalities
# 4                                          Lambdas
# ...

# %%
af1 = pd.read_csv("/content/Raw_Skills_Dataset.csv")

# %%
af1['lables']=None

# %%
for i in range(34116):
  af1['lables'][i]=af['lable'][i]

# %%
af1
# Out:
#                                             RAW DATA         lables
# 0                                           What ifs  Non technical
# 1                                          seniority  Non technical
# 2                                        familiarity  Non technical
# 3                                    functionalities  Non technical
# 4                                            Lambdas  Non technical
# ...                                              ...            ...
# 34111                                    negotiation  Non technical
# 34112                                      deadlines  Non technical
# 34113  Self-motivated, enthusiastic and strong drive  Non technical
# 34114                                    negotiation  Non technical
# 34115                                      deadlines  Non technical
#
# [34116 rows x 2 columns]

# %%
af1.to_csv('raw_lables.csv',index=False)

# %%
! ls
# Out:
# Example_Technical_Skills.csv  Raw_Skills_Dataset.csv
# raw_lables.csv		      sample_data
